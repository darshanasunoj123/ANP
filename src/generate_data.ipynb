# %% [markdown]
# <a href="https://colab.research.google.com/github/darshanasunoj123/ANP/blob/main/src/generate_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import logging
from pydantic import BaseModel
from typing import Optional
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from newsapi import NewsApiClient
#os.chdir('ANP')

# %%
#Creating logs
logger = logging.getLogger("pipeline logs")
logger.setLevel(logging.INFO)

#Making directory and files
os.makedirs("logs", exist_ok=True)

#Creating a file handler to write logs to a file
file_handler = logging.FileHandler("logs/pipeline.log")
file_handler.setLevel(logging.INFO)

#Creating a console handler to write logs to the console
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)

#Adding handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# %%
# Scraping newsapi

# Setting up the client
newsapi = NewsApiClient(userdata.get('NEWS_API'))

#Scraping news articles related to nuclear energy
raw_nuclear = newsapi.get_everything(q='nuclear energy',
                                  language='en',
                                  from_param='2026-05-18',
                                  to='2026-06-18',
                                  page=1)

# %%
# Data from yfinance

import yfinance as yf

list_of_tickers = ['URA','NLR','URNM','NUKZ']

ticker_objects =[]

for ticker in list_of_tickers:
  ticker_objects.append(yf.Ticker(ticker))

data_tickers = yf.download(list_of_tickers, start='2026-05-18', end='2026-06-18')

print(data_tickers)

# %%
# !pip install apify-client

# %%
#Scraping from motley fool

# %%
# Moving data to data files

data_tickers.to_csv('data/data_tickers.csv')

with open('data/raw_nuclear.json', 'w') as f:
  json.dump(raw_nuclear,f)
